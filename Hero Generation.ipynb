# %%
import random as rd
#import sys

#heroclass = ['Archer', 'Assassin', 'Berserker', 'Caster', 'Lancer', 'Rider', 'Saber'];
heroclass = [ 'Assassin'];
#heroclass = ['Caster'];
herotraitB = ['Divinity', 'Nobility', 'Obliteration', 'Resurrection', 'Instantaneous Movement','Luck'];
Alignment = ['Lawful good', 'Lawful good', 'Lawful Neutral', 'Lawful Evil', 'Neutral Good', 'Neutral Good', 'True Neutral','Neutral Evil','Chaotic Good', 'Chaotic Good', 'Chaotic Neutral','Chaotic Evil'];
AlignmentChoice = rd.choice(Alignment)
herochoice = rd.choice(heroclass)
herotraitBchoice = rd.choice(herotraitB)
NoblePhantasm = rd.randint(1,6);
#NoblePhantasm = 6;
Armament = rd.randint(1,6);
BurnCostA = 0; BurnCostB = 0; Innate = ''; PhantasmDesc = ''; PhantasmName = ''; ArmName = ''; ArmDesc = '';

HD = 20 ; BAB = 20; Burn = 1; armor = 10; deflect = 3; natural = 3; ACMod = 0; DR = '10/magic'; FH = 10; HP = 0; SR = 15;
s = rd.randint(10,35); d = rd.randint(10,35); c = rd.randint(10,35); i = rd.randint(10,35); w = rd.randint(10,35); ca = rd.randint(10,35); 
Basehp = rd.randint(90,180)

# %%
if herotraitBchoice == 'Divinity':
    Innate = 'all stats +5'
    
elif herotraitBchoice == 'Nobility':
    Innate = 'Frightful Presence DC (20 + cha)'
    
elif herotraitBchoice == 'Obliteration':
    Damagetype = ['Arcane', 'Holy', 'Unholy'];
    Damage = rd.choice(Damagetype);
    Innate = 'Gain the ability to Deal 20d6 %s damage in a 120 ft. line, save dc (20+con)' %(Damage)
    BurnCostB += 5
    
elif herotraitBchoice == 'Resurrection':
    Innate = 'Upon death resurrect to full health, but is stunned for 1 round and staggered for 1d4 rounds.'
    BurnCostB += 5

elif herotraitBchoice == 'Instantaneous Movement':
    Innate = 'As an Immediate Action can teleport 30 ft. If used in reaction to an attack, it has a 50% miss chance. This is a supernatural effect for Caster but is an extraordinary effect for all other classes.'
    BurnCostB += 5

elif herotraitBchoice == 'Luck':
    Innate = 'Reroll a dice the hero rolls.'
    BurnCostB += 4

# %%
if herochoice == 'Berserker':
    if s < 15:
        s = 15
    s = s + 8
    c = c + 8
    ACMod = -2
    if herotraitB == 'Divinity':
        s += 5; d += 5; c += 5; i += 5; w += 5; ca += 5;
    HP = Basehp + 20 + 20* int((c-10)/2)
    Special = 'Mad Enhancement [Mighty Rage(permanent, +8 str, +8 con, +4 will saves, -2 AC, cannot use Dex, Con, Int based skills are unusable)]'
    
    if NoblePhantasm == 1:
        PhantasmName = 'Weapon Mastery'
        PhantasmDesc = 'Any attacks made with a weapon automatically confirm all critical threats and have their damage multiplier increased by 1 (×2 becomes ×3, for example). In addition, he cannot be disarmed'
    elif NoblePhantasm == 2:
        PhantasmName = 'Divine Fortitude'
        PhantasmDesc = 'dr 10/-'
        DR = '10/-'
    elif NoblePhantasm == 3:
        PhantasmName = 'Unarmed Combat'
        PhantasmDesc = 'Gain Improved Unarmed Strike, deal 2d10 damage and flurry of blows as 20th level monk'
    elif NoblePhantasm == 4:
        PhantasmName = 'Battle Continuation'
        PhantasmDesc = 'Become immune to bleed, death attacks, exhaustion, fatigue, nausea effects, negative levels, and sickened effects. Ability damage and drain cannot reduce you below 1 in any ability score.  When you are below 0 hit points, you do not die until your negative total is in excess of twice your Constitution score and are not staggered.'
    elif NoblePhantasm == 5:
        PhantasmName = 'Brute'
        PhantasmDesc = 'str +8, dex +8, con +8, -2 int, -2 wis, -2 cha as size bonuses. Activating this ability is a free action that costs 1 point of burn to maintain each round.'
    elif NoblePhantasm == 6:
        PhantasmName = 'Shapechange'
        PhantasmDesc = 'Permanent Shapechange spell as a supernatural ability'

elif herochoice == 'Saber':
    if s < 30:
        s = 30
    if d < 25:
        d = 25
    if c < 25:
        c = 25
    if i < 20:
        i = 20
    if w < 20:
        w = 20
    if ca < 20:
        c = 20
    if herotraitB == 'Divinity':
        s += 5; d += 5; c += 5; i += 5; w += 5; ca += 5;
    HP = Basehp + 20 + 20* int((c-10)/2)
    Special = 'Spell Resistance[SR 25]. Spells that come into contact with saber of 6th level or lower are subject to a dispel check of +20.'
    SR = SR + 10
    
    if NoblePhantasm == 1:
        PhantasmName = 'Weapon Mastery'
        PhantasmDesc = 'Any attacks made with a weapon automatically confirm all critical threats and have their damage multiplier increased by 1 (×2 becomes ×3, for example). In addition, he cannot be disarmed'
    elif NoblePhantasm == 2:
        PhantasmName = 'Favored Soul'
        PhantasmDesc = 'Lay on hands as a 20th level paladin inclduing mercies.'
    elif NoblePhantasm == 3:
        PhantasmName = 'Blade Study'
        PhantasmDesc = 'As a swift action, gain a +5 bonus on Bluff, Knowledge, Perception, Sense Motive, and Survival checks attempted against the target, and a +5 bonus on weapon attack rolls and weapon damage rolls against it.'
    elif NoblePhantasm == 4:
        PhantasmName = 'Untouchable'
        PhantasmDesc = 'Elemental Resistance 20, SR +5'
        SR = SR + 5
    elif NoblePhantasm == 5:
        PhantasmName = 'Heedless Assualt'
        PhantasmDesc = 'Gain Pounce, and Power attack. The penalty from power attack may be applied to AC instead of to hit.'
    elif NoblePhantasm == 6:
        PhantasmName = 'Finesseful Fighter'
        PhantasmDesc = 'Gain [Combat Expertise, Improved Disarm, Greater Disarm, Improved Feint, Greater Feint, Improved Trip, Greater Trip, and gain a +5 enhancement bonus to your ability check to perform any of these feats.]'
    
elif herochoice == 'Caster':
    BAB = BAB - 10
    Burn = Burn - 1
    armor = armor - 5;
    
    if s > 20:
        s = s-10
    if d > 20:
        d = d-10
    if c > 20:
        c = c-10
    if i < 30:
        i = 30
    if w < 30:
        w = 30
    if ca < 30:
        ca = 30
    if herotraitB == 'Divinity':
        s += 5; d += 5; c += 5; i += 5; w += 5; ca += 5;
    HP = Basehp - 20 + 20* int((c-10)/2)
    
    if NoblePhantasm == 1:
        PhantasmName = 'Ultimate Magus'
        PhantasmDesc = 'A spell the caster sees is immediately placed on his spell list, potentially allowing him to counterspell. Gain Intensified spell as a bonus feat.'
        CastingType = ['Arcane int based', 'Arcane cha based'];
        Casting = rd.choice(CastingType);
        Spellsknown = ['Infernal Sorcerer school', 'Draconic Sorcerer school', 'Destruction Cleric Domain', 'Abberant Sorcerer school']
        Spells = rd.choice(Spellsknown);
        Special = 'Spellcasting [Can spontaneously cast %s spells of each level up to 9th 6 times per day without need for material components. Spells known as %s.]' %(Casting, Spells)
    elif NoblePhantasm == 2:
        PhantasmName = 'Evoker'
        PhantasmDesc = '(Su): Can sacrifice a spell slot to create a sphere of elemental damage with a 20 ft radius that deals 3d6 damage per spell level of any element. Ref save DC (20 + highest ability modifier)'
        CastingType = ['Arcane int based', 'Divine wisdom based', 'Arcane cha based', 'Divine cha based'];
        Casting = rd.choice(CastingType);
        Spellsknown = ['Transformation Witch Patron', 'Trickery Witch school', 'Abberant Sorcerer school']
        Spells = rd.choice(Spellsknown);
        Special = 'Spellcasting [Can spontaneously cast %s spells of each level up to 9th 6 times per day without need for material components. Spells known as %s.]' %(Casting, Spells)
    elif NoblePhantasm == 3:
        PhantasmName = 'Master Summoner'
        PhantasmDesc = 'One summon monster spell gains permanence, learn all summon monster spells. Summoned Monsters have +5 to all stats.'
        CastingType = ['Arcane int based', 'Divine wisdom based', 'Arcane cha based', 'Divine cha based'];
        Casting = rd.choice(CastingType);
        Spellsknown = ['Shadow Witch Patron', 'Deception Witch Patron', 'Destruction Cleric Domain', 'Abberant Sorcerer school']
        Spells = rd.choice(Spellsknown);
        Special = 'Spellcasting [Can spontaneously cast %s spells of each level up to 9th 6 times per day without need for material components. Spells known as %s.]' %(Casting, Spells)
    elif NoblePhantasm == 4:
        PhantasmName = 'Unchained Mind'
        PhantasmDesc = 'Incorporeal, greater possession at will DC 20'
        CastingType = ['Arcane int based', 'Arcane cha based'];
        Casting = rd.choice(CastingType);
        Spellsknown = ['Shadow Witch Patron', 'Destruction Cleric Domain']
        Spells = rd.choice(Spellsknown);
        Special = 'Spellcasting [Can spontaneously cast %s spells of each level up to 9th 6 times per day without need for material components. Spells known as %s.]' %(Casting, Spells)
    elif NoblePhantasm == 5:
        PhantasmName = 'Gish'
        PhantasmDesc = 'Gain the full benefits of the arcane bloodline and bloodrage as a 20th level bloodrager. This character can casts spells 4th level and below under the effects of bloodrage.'
        CastingType = ['Arcane int based', 'Arcane cha based'];
        Casting = rd.choice(CastingType);
        Spellsknown = ['Fey sorcerer school', 'Destined sorcerer school']
        Spells = rd.choice(Spellsknown);
        Special = 'Spellcasting [Can spontaneously cast %s spells of each level up to 9th 6 times per day without need for material components. Spells known as %s.]' %(Casting, Spells)
    elif NoblePhantasm == 6:
        PhantasmName = 'Lichdom'
        PhantasmDesc = 'caster becomes a lich, refer to lich template for changes.'
        CastingType = ['Arcane int based', 'Divine wisdom based', 'Arcane cha based', 'Divine cha based'];
        Casting = rd.choice(CastingType);
        Spellsknown = ['Destruction Cleric Domain', 'Death Cleric Domain', 'Abberant Sorcerer school']
        Spells = rd.choice(Spellsknown);
        Special = 'Spellcasting [Can spontaneously cast %s spells of each level up to 9th 6 times per day without need for material components. Spells known as %s.]' %(Casting, Spells)
    
elif herochoice == 'Archer':
    if s < 20:
        s = 20
    if d < 20:
        d = 20
    if c < 20:
        c = 20
    if herotraitB == 'Divinity':
        s += 5; d += 5; c += 5; i += 5; w += 5; ca += 5;
    HP = Basehp + 20* int((c-10)/2)
    Special = 'Archery[Point Blank Shot,Far Shot, Precise Shot, Improved Precise Shot, Pinpoint Targeting, Shot on The Run, Rapid Shot, Manyshot], Autonomy [can still act for a day after master dies]'
    
    if NoblePhantasm == 1:
        PhantasmName = 'Zen Archery'
        PhantasmDesc = 'Add your wisdom modifier to your attack roll and damage.'
    elif NoblePhantasm == 2:
        PhantasmName = 'Deadly Aim'
        PhantasmDesc = 'Gain a +12 damage bonus on ranged attacks.'
    elif NoblePhantasm == 3:
        PhantasmName = 'Gunslinger'
        PhantasmDesc = 'Gain Grit, Gun training, and Deeds as a 20th level Gunslinger.'
    elif NoblePhantasm == 4:
        PhantasmName = 'Time Stands Still'
        PhantasmDesc = 'Gain the ability to speed up and perform 2 full attack actions as a standard action for 5 points of burn'
    elif NoblePhantasm == 5:
        PhantasmName = 'Apocalypse from the Sky'
        PhantasmDesc = 'Gain the ability to make one attack at the highest bab against all targets within the first range increment of your bow. For each attack make two attack rolls and use the highest roll.'
    elif NoblePhantasm == 6:
        PhantasmName = 'Gate of Babylon'
        PhantasmDesc = 'For every attack, roll a 1d3 to determine if the weapon is bludgeoning, piercing or slashing, then roll a d100 to determine the quality of the weapon based on a combination of rolls from the +2 melee weapon special abilities table, and the +3 melee weapon table, or a single roll on the +4/+5 melee weapon table. Use Cha instead of dex to determine your chance to hit and damage.'
    
elif herochoice == 'Assassin':
    BAB = BAB - 5
    if s > 20:
        s -= 10
    if d < 25:
        d = 25
    if c < 15:
        c = 15
    if c > 20:
        c = 20
    if herotraitB == 'Divinity':
        s += 5; d += 5; c += 5; i += 5; w += 5; ca += 5;
    HP = Basehp + 20* int((c-10)/2)
    Special = 'Concealment [Hide in Plain Sight, Darkvision, Nondetection, take 15 on stealth], weapon finesse.'
    
    if NoblePhantasm == 1:
        PhantasmName = 'Hassan'
        PhantasmDesc = 'Start with 12 copies of this hero, all skills rank 20. Hassan gains no benefit from innate abilities or armament until only one Hassan is left. Gain the ability to ignore intercept 3 times per round across all members of Hassan.'
    elif NoblePhantasm == 2:
        PhantasmName = 'Hassan'
        PhantasmDesc = 'Start with 12 copies of this hero, all skills rank 20. Hassan gains no benefit from innate abilities or armament until only one Hassan is left. Gain the ability to ignore intercept 3 times per round across all members of Hassan.'
    elif NoblePhantasm == 3:
        PhantasmName = 'Hassan'
        PhantasmDesc = 'Start with 12 copies of this hero, all skills rank 20. Hassan gains no benefit from innate abilities or armament until only one Hassan is left. Gain the ability to ignore intercept 3 times per round across all members of Hassan.'
    elif NoblePhantasm == 4:
        PhantasmName = 'Hassan'
        PhantasmDesc = 'Start with 12 copies of this hero, all skills rank 20. Hassan gains no benefit from innate abilities or armament until only one Hassan is left. Gain the ability to ignore intercept 3 times per round across all members of Hassan.'
    elif NoblePhantasm == 5:
        PhantasmName = 'Hassan'
        PhantasmDesc = 'Start with 12 copies of this hero, all skills rank 20. Hassan gains no benefit from innate abilities or armament until only one Hassan is left. Gain the ability to ignore intercept 3 times per round across all members of Hassan.'
    elif NoblePhantasm == 6:
        PhantasmName = 'Tsubame Gaeshi'
        PhantasmDesc = 'Perfect strike as monk level 20, Combat expertise, Greater vital strike and Improved devastating strike, (weapon damage roll 4 times +1 damager per dice roll to maximum of 6) usable any weapon'
    
elif herochoice == 'Lancer':
    if s < 25:
        s = 25
    if d < 30:
        d = 30
    if c < 20:
        c = 20
    if i < 15:
        i = 15
    if w < 15:
        w = 15
    if ca < 15:
        ca = 15
    if herotraitB == 'Divinity':
        s += 5; d += 5; c += 5; i += 5; w += 5; ca += 5;
    HP = Basehp + 20* int((c-10)/2)
    Special = 'Lance[Combat Reflexes, Reach(+5 feet to all lancelike weapons)], +10 ft base movement speed'
    
    if NoblePhantasm == 1:
        PhantasmName = 'Weapon Mastery'
        PhantasmDesc = 'Any attacks made with a weapon automatically confirm all critical threats and have their damage multiplier increased by 1 (×2 becomes ×3, for example). In addition, he cannot be disarmed'
    elif NoblePhantasm == 2:
        PhantasmName = 'Cursed Spear'
        PhantasmDesc = 'Damage caused by your spear is permanent and unhealable.'
    elif NoblePhantasm == 3:
        PhantasmName = 'Minds Eye'
        PhantasmDesc = 'As a swift action, gain a +5 bonus on Bluff, Knowledge, Perception, Sense Motive, and Survival checks attempted against the target, and a +5 bonus on weapon attack rolls and weapon damage rolls against it.'
    elif NoblePhantasm == 4:
        PhantasmName = 'Blinding Speed'
        PhantasmDesc = 'Reach +10 ft.'
    elif NoblePhantasm == 5:
        PhantasmName = 'Skirmisher'
        PhantasmDesc = 'Spring attack, Bounding Assualt, Rapid Blitz. Any time during your movement make up to 3 attacks, each attack after the first takes a -5 attack penalty'
    elif NoblePhantasm == 6:
        PhantasmName = 'Elusive Target'
        PhantasmDesc = 'Make a 15 ft. step as a free action.'
    
elif herochoice == 'Rider':
    BAB = BAB - 5
    
    if d < 25:
        d = 25
    if i < 20:
        i = 20
    if w < 20:
        w = 20
    if ca < 20:
        ca = 20
    if herotraitB == 'Divinity':
        s += 5; d += 5; c += 5; i += 5; w += 5; ca += 5;
    HP = Basehp + 20* int((c-10)/2)
    Special = 'Mount[As paladin divine bond level 20]'
    
    if NoblePhantasm == 1:
        PhantasmName = 'Homonculus'
        PhantasmDesc = 'Instead of a mount use the homonculus table for alchemists. Gain infusions as a 20th level alchemist'
    elif NoblePhantasm == 2:
        PhantasmName = 'Pegasus'
        PhantasmDesc = 'The base mount is a pegasus.'
    elif NoblePhantasm == 3:
        PhantasmName = 'Evershifting form'
        PhantasmDesc = 'The base mount gains shapechange as a supernatural ability.'
    elif NoblePhantasm == 4:
        PhantasmName = 'Dragon Knight'
        PhantasmDesc = 'The base mount is a wyrmling dragon of your choosing.'
    elif NoblePhantasm == 5:
        PhantasmName = 'Chariot'
        PhantasmDesc = 'Mount Gains [Trample, Improved Overrrun, Greater overrun], You made add half your strength modifier to the trample attempt of your mount'
    elif NoblePhantasm == 6:
        PhantasmName = 'Legendary Beast'
        PhantasmDesc = 'Mount gains 26 evolution points.'
    
strmod = int((s-10)/2)
dexmod = int((d-10)/2)
conmod = int((c-10)/2)
intmod = int((i-10)/2)
wismod = int((w-10)/2)
chamod = int((c-10)/2)

INIT = dexmod
TotalAC = armor + deflect + natural + dexmod + 10 + ACMod
TouchAC = deflect + dexmod + 10 + ACMod

fort = 12 + conmod
ref = 12 + dexmod
will = 12 + wismod

# %%
if Armament == 1:
    ArmName = 'Beacon of Self'
    ArmDesc = 'Can use a power as a command word, suffuses hero with an aura of the following colors based on alignment, DC (20 + cha). Chaotic (violet flame): Word of chaos once per day on command. Good (white flame): Allies within 30 feet of the beacon gain the benefits of protection from evil and heroism. Evil (black flame): Bearer is constantly under the effect of protection from good and may use harm twice per day. Lawful (golden flame): Dictum once per day on command.'
    
elif Armament == 2:
    ArmName = 'Indomitable Armor'
    ArmDesc = 'Change armor bonus to +14, reduce speed to 30 ft. Gain a 75% chance to negate a critical hit or sneak attack.'
    armor = 14
    TotalAC = armor + deflect + natural + dexmod + 10 + ACMod
    
elif Armament == 3:
    ArmName = 'Charisma'
    ArmDesc = 'The authority of the hero is so great it is like a curse. Command the obedience and fealty of creatures within 120 feet as a standard action. Creatures totaling 150 Hit Dice can be ruled, but creatures with Intelligence scores of 12 or higher are each entitled to a DC 16 Will save to negate the effect. Ruled creatures obey the wielder as if she were their absolute sovereign. Still, if the wielder gives a command that is contrary to the nature of the creatures commanded, the magic is broken.'
    BurnCostA = BurnCostA + 5
    
elif Armament == 4:
    ArmName = 'Eye of the Mind'
    ArmDesc = 'Gain a powerful sixth sense. You are never surprised or flat-footed and you gain a general idea of what action you might take to best protect yourself. Gain a +2 insight bonus to AC and on Reflex saves'
    TotalAC = armor + deflect + natural + dexmod + 10 + ACMod + 2
    TouchAC = deflect + dexmod + 10 + ACMod + 2
    ref = 12 + dexmod + 2
    
elif Armament == 5:
    ArmName = 'Augmentation'
    ArmDesc = 'As a free action each round choose between: +5 movement speed, +1 bonus to hit, +2 bonus to damage, +5 bonus to skill check, +1 bonus to saving throw dc, +1 bonus to saving throws'

elif Armament == 6:
    ArmName = 'Protection from spells'
    ArmDesc = 'Spell Resistance + 10.'
    SR = SR + 10

# %%
#print "%s [%s]" %(herochoice, AlignmentChoice)

#sys.stdout = open("HeroGeneration.txt", "w")
print "%s [%s]" %(herochoice, AlignmentChoice)
print "%d HD (%d HP)" %(HD, HP)
print "AC: %d (10 + %d Armor + %d dex + %d def + %d nat)" %(TotalAC, armor, dexmod ,deflect, natural)
print "Touch AC: %d" %(TouchAC)
print "Initiative: +%d" %(INIT)
print "DR: %s" %(DR)
print "SR: %d" %(SR)
print "Fast Healing: %s" %(FH)
print "BAB: +%d" %(BAB)
print "Speed: 60 ft."
print "Ability Scores:"
print "str %d dex %d con %d int %d wis %d cha %d  " %(s, d, c, i, w, ca)
print "Saving Throws:"
print "fortitude +%d, reflex +%d, will +%d" %(fort, ref, will)
print "Hero Upkeep Cumulative Burn cost per day: %s" %(Burn)
print "Class Ability:"
print (Special)
print "Innate Ability:"
print (herotraitBchoice)
print (Innate)
print "Burn cost of Innate Ability: %s" %(BurnCostB)
print "Noble Phantasm:"
print (PhantasmName)
print (PhantasmDesc)
print "Armament:"
print (ArmName)
print (ArmDesc)
#sys.stdout.close()
# Out:
# Assassin [Neutral Good]
# 20 HD (213 HP)
# AC: 40 (10 + 10 Armor + 12 dex + 3 def + 3 nat)
# Touch AC: 27
# Initiative: +12
# DR: 10/magic
# SR: 15
# Fast Healing: 10
# BAB: +15
# Speed: 60 ft.
# Ability Scores:
# str 23 dex 34 con 20 int 31 wis 17 cha 20
# Saving Throws:
# fortitude +17, reflex +26, will +15
# Hero Upkeep Cumulative Burn cost per day: 1
# Class Ability:
# Concealment [Hide in Plain Sight, Darkvision, Nondetection, take 15 on stealth], weapon finesse.
# Innate Ability:
# Divinity
# all stats +5
# Burn cost of Innate Ability: 0
# Noble Phantasm:
# Hassan
# Start with 12 copies of this hero, all skills rank 20. Hassan gains no benefit from innate abilities or armament until only one Hassan is left. Gain the ability to ignore intercept 3 times per round across all members of Hassan.
# Armament:
# Eye of the Mind
# ...
